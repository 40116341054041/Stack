# %% [markdown]
# <a href="https://colab.research.google.com/github/40116341054041/Stack/blob/main/Stack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class stack:
  def __init__(self , limit=10):
    self.stack = []
    self.limit = limit
  def peak(self):
    if len(self.stack)<=0:
      return False
    else:
      return self.stack[len(self.stack)-1]
  def pop(self):
    if len(self.stack)<= 0:
      return False
    else:
      return self.stack.pop()
def push(self , data):
  if len(self.stack)>=self.limit:
    return False
  else:
    self.stack.append(data)
def display(self):
  if len(self.stack)<= 0 :
    return False
  else:
    for i in self.stack:
      print(i)

#تابعی بنویسید که عددی را از مبتای 10 به مبنای 10 ببرد
  def is_empty(self):
    if len(number<=0):
      return True
    else:
      return False
  def dec2Bin(number):
    s = stack()
    while(number>0) :
      r = number% 2
      s.push(r)
      number = number//2
    b = "  "
    while not s.is empty():
      b=b+str(s.pop())
    return b


#تابعی بنویسید که محتوای یک لیست را معکوس کند
  def reverse(lst):
    s = stack()
    for e in lst:
      s.push(e)
    for i in range(lent(lst)):
      lst[i] = s.pop()


#تابعی بنئیسید که محتوای یک استک زا معکوس کند
  def reverse_stack(s):
    s=stack()
    s1=stack()
    s2=stack()
    while not s.is_empty():
      s1.push(s.pop())
    while not s1.is_empty():
      s2.push(s1.pop())
    while not s2.is_empty():
      s.push(s2.pop())


#حاصل عبارت زیر را حساب کنید
#postfix= 74-3*15+/*

  def postfix(lst):
    s = stack((len(lst)//2))
    for e in lst:
      if e == '*':
        t2 = s.pop()
        t1 = s.pop()
        t = t1 * t2
        s.push(t)
      elif '+' , '/' , '-' , '//' :
        t2 = s.pop()
        t1 = s.pop()
        t = t1 * t2
        s.push(t)
      else:
        s.push(e)
    return s.stack[0]


#باز و بسته بودن براکت ها چک شود
  def match_s(str):
    s=stack()
    for i in str:
      if i in '([{':
        s.push(i)
      elif i in  ')]}':
        if s.peak() == i:
          s.pop()
        else:
          return False
    if s.is_empty():
      return True
    else:
      return False
